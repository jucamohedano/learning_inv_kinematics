# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(7,), batch_size=BATCH_SIZE),
        tf.keras.layers.Dense(256, activation='relu', batch_size=BATCH_SIZE),
        tf.keras.layers.Dense(164, activation='relu'),
        tf.keras.layers.Dense(16, name='joints_values')
    ])
    return model

model = build_model()
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (8, 256)                  2048
# _________________________________________________________________
# dense_7 (Dense)              (8, 164)                  42148
# _________________________________________________________________
# joints_values (Dense)        (8, 16)                   2640
# =================================================================
# Total params: 46,836
# Trainable params: 46,836
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=24
init_lr = 1e-2
optimizer = tf.keras.optimizers.Adam(lr=init_lr)
# optimizer = tf.keras.optimizers.SGD(lr=init_lr, momentum=0.9)

model.compile(
    optimizer = optimizer,
    loss = tf.keras.losses.MeanSquaredError(),
    metrics=[tf.keras.metrics.MeanSquaredError()])


history = model.fit(train_batches, validation_data=train_val, epochs=epochs)
# Out:
# Epoch 1/24
# 16000/16000 [==============================] - 9s 544us/step - loss: 0.0574 - mean_squared_error: 0.0574 - val_loss: 0.0626 - val_mean_squared_error: 0.0626
# Epoch 2/24
# 16000/16000 [==============================] - 9s 544us/step - loss: 0.0569 - mean_squared_error: 0.0569 - val_loss: 0.0596 - val_mean_squared_error: 0.0596
# Epoch 3/24
# 16000/16000 [==============================] - 9s 547us/step - loss: 0.0569 - mean_squared_error: 0.0569 - val_loss: 0.0634 - val_mean_squared_error: 0.0634
# Epoch 4/24
# 16000/16000 [==============================] - 9s 540us/step - loss: 0.0572 - mean_squared_error: 0.0572 - val_loss: 0.0601 - val_mean_squared_error: 0.0601
# Epoch 5/24
# 16000/16000 [==============================] - 9s 547us/step - loss: 0.0573 - mean_squared_error: 0.0573 - val_loss: 0.0643 - val_mean_squared_error: 0.0643
# Epoch 6/24
# 16000/16000 [==============================] - 9s 545us/step - loss: 0.0579 - mean_squared_error: 0.0579 - val_loss: 0.0636 - val_mean_squared_error: 0.0636
# Epoch 7/24
# 16000/16000 [==============================] - 9s 536us/step - loss: 0.0577 - mean_squared_error: 0.0577 - val_loss: 0.0688 - val_mean_squared_error: 0.0688
# Epoch 8/24
# 16000/16000 [==============================] - 9s 532us/step - loss: 0.0577 - mean_squared_error: 0.0577 - val_loss: 0.0617 - val_mean_squared_error: 0.0617
# Epoch 9/24
# 16000/16000 [==============================] - 9s 542us/step - loss: 0.0575 - mean_squared_error: 0.0575 - val_loss: 0.0608 - val_mean_squared_error: 0.0608
# Epoch 10/24
# 16000/16000 [==============================] - 9s 554us/step - loss: 0.0575 - mean_squared_error: 0.0575 - val_loss: 0.0601 - val_mean_squared_error: 0.0601
# Epoch 11/24
# 16000/16000 [==============================] - 9s 541us/step - loss: 0.0578 - mean_squared_error: 0.0578 - val_loss: 0.0630 - val_mean_squared_error: 0.0630
# Epoch 12/24
# 16000/16000 [==============================] - 9s 530us/step - loss: 0.0578 - mean_squared_error: 0.0578 - val_loss: 0.0716 - val_mean_squared_error: 0.0716
# Epoch 13/24
# 16000/16000 [==============================] - 9s 530us/step - loss: 0.0576 - mean_squared_error: 0.0576 - val_loss: 0.0584 - val_mean_squared_error: 0.0584
# Epoch 14/24
# 16000/16000 [==============================] - 9s 532us/step - loss: 0.0576 - mean_squared_error: 0.0576 - val_loss: 0.0637 - val_mean_squared_error: 0.0637
# Epoch 15/24
# 16000/16000 [==============================] - 9s 531us/step - loss: 0.0583 - mean_squared_error: 0.0583 - val_loss: 0.0600 - val_mean_squared_error: 0.0600
# Epoch 16/24
# 16000/16000 [==============================] - 9s 534us/step - loss: 0.0580 - mean_squared_error: 0.0580 - val_loss: 0.0627 - val_mean_squared_error: 0.0627
# Epoch 17/24
# 16000/16000 [==============================] - 9s 533us/step - loss: 0.0577 - mean_squared_error: 0.0577 - val_loss: 0.0683 - val_mean_squared_error: 0.0683
# Epoch 18/24
# 16000/16000 [==============================] - 9s 531us/step - loss: 0.0581 - mean_squared_error: 0.0581 - val_loss: 0.0651 - val_mean_squared_error: 0.0651
# Epoch 19/24
# 16000/16000 [==============================] - 9s 531us/step - loss: 0.0579 - mean_squared_error: 0.0579 - val_loss: 0.0616 - val_mean_squared_error: 0.0616
# Epoch 20/24
# 16000/16000 [==============================] - 9s 530us/step - loss: 0.0579 - mean_squared_error: 0.0579 - val_loss: 0.0631 - val_mean_squared_error: 0.0631
# Epoch 21/24
# 16000/16000 [==============================] - 9s 542us/step - loss: 0.0579 - mean_squared_error: 0.0579 - val_loss: 0.0637 - val_mean_squared_error: 0.0637
# Epoch 22/24
# 16000/16000 [==============================] - 9s 571us/step - loss: 0.0580 - mean_squared_error: 0.0580 - val_loss: 0.0637 - val_mean_squared_error: 0.0637
# Epoch 23/24
# 16000/16000 [==============================] - 9s 549us/step - loss: 0.0581 - mean_squared_error: 0.0581 - val_loss: 0.0667 - val_mean_squared_error: 0.0667
# Epoch 24/24
# 16000/16000 [==============================] - 9s 548us/step - loss: 0.0582 - mean_squared_error: 0.0582 - val_loss: 0.0705 - val_mean_squared_error: 0.0705

# %%
# metric_loss = history.history['mean_squared_error']
# val_metric_loss = history.history['val_mean_squared_error']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
# plt.subplot(1, 2, 1)
plt.plot(epochs_range, loss, label='loss')
plt.plot(epochs_range, val_loss, label='val_loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

# plt.subplot(1, 2, 2)
# plt.plot(epochs_range, metric_loss, label='mean_squared_error')
# plt.plot(epochs_range, val_metric_loss, label='val_mean_squared_error')
# plt.legend(loc='upper right')
# plt.title('Training and Validation Accuracy')

plt.show()

# %%
ds = test_ds.map(lambda x,y: (x,tf.reshape(y, [-1]))).batch(BATCH_SIZE).prefetch(1)
results = model.evaluate(ds, batch_size=8)
model.predict(ds.take(1).take(1))
# Out:
# 2000/2000 [==============================] - 1s 267us/step - loss: 0.0860 - mean_squared_error: 0.0860
# array([[-6.67601405e-03,  6.98526463e-08, -4.15184677e-01,
#          8.42231691e-01, -1.58198476e-01,  2.85582792e-05,
#          4.08178403e-06,  1.27008820e+00, -2.11903639e-03,
#         -1.37780607e-02, -5.68875344e-04,  1.00629747e+00,
#         -1.57170068e-03, -4.50741034e-04,  3.48562419e-01,
#          2.99818695e-01],
#        [-7.13801803e-03,  7.70295117e-08, -4.43502724e-01,
#          9.02364552e-01, -2.29323149e-01,  3.10733485e-05,
#          4.40058875e-06,  1.32826018e+00, -2.35947710e-03,
#         -6.83819652e-02, -6.23039785e-04,  1.03254747e+00,
#         -1.52566633e-03, -4.83842508e-04,  3.04524422e-01,
#          3.11471254e-01],
#        [-6.96378388e-03,  7.31022496e-08, -4.91124332e-01,
#          9.69089448e-01, -2.42794454e-01,  3.17369886e-05,
#          4.55817872e-06,  1.34206581e+00, -1.78222754e-03,
#         -5.18154502e-02, -6.03157096e-04,  1.01312947e+00,
#         -1.25538954e-03, -4.76338551e-04,  3.81027758e-01,
#          2.89304852e-01],
#        [-6.55673537e-03,  6.29419290e-08, -6.00493968e-01,
#          9.99282420e-01, -2.09191084e-01,  3.05415488e-05,
#          4.42632199e-06,  1.31663394e+00, -1.02403294e-03,
#          1.19195580e-02, -5.44800016e-04,  9.69251990e-01,
#         -1.22793484e-03, -4.51311993e-04,  5.11787474e-01,
#          2.55171061e-01],
#        [-6.25932263e-03,  5.55263604e-08, -6.92594826e-01,
#          1.02390885e+00, -1.82465076e-01,  2.94629372e-05,
#          4.29113243e-06,  1.29634964e+00, -6.37085701e-04,
#          7.10276067e-02, -4.98791982e-04,  9.26575005e-01,
#         -1.19182584e-03, -4.33583802e-04,  5.74328959e-01,
#          2.40475059e-01],
#        [-6.07523695e-03,  5.18734709e-08, -7.28361309e-01,
#          1.02789640e+00, -1.62585735e-01,  2.85596907e-05,
#          4.16391003e-06,  1.28068662e+00, -6.79584628e-04,
#          1.10144615e-01, -4.71533509e-04,  8.98173392e-01,
#         -1.13942230e-03, -4.22045938e-04,  5.66529870e-01,
#          2.51668662e-01],
#        [-5.98368607e-03,  5.11402547e-08, -7.23576963e-01,
#          1.01521218e+00, -1.50301099e-01,  2.78000898e-05,
#          4.03154081e-06,  1.27018404e+00, -1.14744739e-03,
#          1.31575346e-01, -4.59838513e-04,  8.82170200e-01,
#         -1.07768725e-03, -4.15049202e-04,  4.98951912e-01,
#          2.94166505e-01],
#        [-5.86812198e-03,  5.17840490e-08, -6.62085235e-01,
#          9.79988396e-01, -1.29566967e-01,  2.67880496e-05,
#          3.87668342e-06,  1.25247931e+00, -1.77656603e-03,
#          1.47926003e-01, -4.50808235e-04,  8.71943772e-01,
#         -9.71029396e-04, -4.05614323e-04,  3.96714926e-01,
#          3.44470859e-01]], dtype=float32)

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(7,), batch_size=BATCH_SIZE),
        tf.keras.layers.Dense(256, activation='relu', batch_size=BATCH_SIZE),
        tf.keras.layers.Dense(164, activation='relu'),
        tf.keras.layers.Dense(16, name='joints_values')
    ])
    return model

model = build_model()
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (8, 256)                  2048
# _________________________________________________________________
# dense_9 (Dense)              (8, 164)                  42148
# _________________________________________________________________
# joints_values (Dense)        (8, 16)                   2640
# =================================================================
# Total params: 46,836
# Trainable params: 46,836
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=24
init_lr = 1e-3
optimizer = tf.keras.optimizers.Adam(lr=init_lr)
# optimizer = tf.keras.optimizers.SGD(lr=init_lr, momentum=0.9)

model.compile(
    optimizer = optimizer,
    loss = tf.keras.losses.MeanSquaredError(),
    metrics=[tf.keras.metrics.MeanSquaredError()])


history = model.fit(train_batches, validation_data=train_val, epochs=epochs)
# Out:
# Epoch 1/24
# 16000/16000 [==============================] - 9s 542us/step - loss: 0.0490 - mean_squared_error: 0.0490 - val_loss: 0.0547 - val_mean_squared_error: 0.0547
# Epoch 2/24
# 16000/16000 [==============================] - 9s 534us/step - loss: 0.0455 - mean_squared_error: 0.0455 - val_loss: 0.0534 - val_mean_squared_error: 0.0534
# Epoch 3/24
# 16000/16000 [==============================] - 9s 522us/step - loss: 0.0441 - mean_squared_error: 0.0441 - val_loss: 0.0518 - val_mean_squared_error: 0.0518
# Epoch 4/24
# 16000/16000 [==============================] - 8s 518us/step - loss: 0.0429 - mean_squared_error: 0.0429 - val_loss: 0.0540 - val_mean_squared_error: 0.0540
# Epoch 5/24
# 16000/16000 [==============================] - 8s 519us/step - loss: 0.0422 - mean_squared_error: 0.0422 - val_loss: 0.0522 - val_mean_squared_error: 0.0522
# Epoch 6/24
# 16000/16000 [==============================] - 9s 520us/step - loss: 0.0417 - mean_squared_error: 0.0417 - val_loss: 0.0536 - val_mean_squared_error: 0.0536
# Epoch 7/24
# 16000/16000 [==============================] - 9s 523us/step - loss: 0.0409 - mean_squared_error: 0.0409 - val_loss: 0.0516 - val_mean_squared_error: 0.0516
# Epoch 8/24
# 16000/16000 [==============================] - 9s 521us/step - loss: 0.0404 - mean_squared_error: 0.0404 - val_loss: 0.0514 - val_mean_squared_error: 0.0514
# Epoch 9/24
# 16000/16000 [==============================] - 9s 523us/step - loss: 0.0401 - mean_squared_error: 0.0401 - val_loss: 0.0503 - val_mean_squared_error: 0.0503
# Epoch 10/24
# 16000/16000 [==============================] - 9s 526us/step - loss: 0.0396 - mean_squared_error: 0.0396 - val_loss: 0.0539 - val_mean_squared_error: 0.0539
# Epoch 11/24
# 16000/16000 [==============================] - 9s 542us/step - loss: 0.0392 - mean_squared_error: 0.0392 - val_loss: 0.0502 - val_mean_squared_error: 0.0502
# Epoch 12/24
# 16000/16000 [==============================] - 9s 536us/step - loss: 0.0388 - mean_squared_error: 0.0388 - val_loss: 0.0521 - val_mean_squared_error: 0.0521
# Epoch 13/24
# 16000/16000 [==============================] - 9s 535us/step - loss: 0.0384 - mean_squared_error: 0.0384 - val_loss: 0.0514 - val_mean_squared_error: 0.0514
# Epoch 14/24
# 16000/16000 [==============================] - 9s 543us/step - loss: 0.0380 - mean_squared_error: 0.0380 - val_loss: 0.0527 - val_mean_squared_error: 0.0527
# Epoch 15/24
# 16000/16000 [==============================] - 9s 539us/step - loss: 0.0378 - mean_squared_error: 0.0378 - val_loss: 0.0524 - val_mean_squared_error: 0.0524
# Epoch 16/24
# 16000/16000 [==============================] - 9s 548us/step - loss: 0.0373 - mean_squared_error: 0.0373 - val_loss: 0.0521 - val_mean_squared_error: 0.0521
# Epoch 17/24
# 16000/16000 [==============================] - 9s 542us/step - loss: 0.0371 - mean_squared_error: 0.0371 - val_loss: 0.0523 - val_mean_squared_error: 0.0523
# Epoch 18/24
# 16000/16000 [==============================] - 9s 546us/step - loss: 0.0369 - mean_squared_error: 0.0369 - val_loss: 0.0517 - val_mean_squared_error: 0.0517
# Epoch 19/24
# 16000/16000 [==============================] - 9s 538us/step - loss: 0.0365 - mean_squared_error: 0.0365 - val_loss: 0.0528 - val_mean_squared_error: 0.0528
# Epoch 20/24
# 16000/16000 [==============================] - 9s 552us/step - loss: 0.0365 - mean_squared_error: 0.0365 - val_loss: 0.0571 - val_mean_squared_error: 0.0571
# Epoch 21/24
# 16000/16000 [==============================] - 9s 537us/step - loss: 0.0362 - mean_squared_error: 0.0362 - val_loss: 0.0525 - val_mean_squared_error: 0.0525
# Epoch 22/24
# 16000/16000 [==============================] - 9s 541us/step - loss: 0.0362 - mean_squared_error: 0.0362 - val_loss: 0.0526 - val_mean_squared_error: 0.0526
# Epoch 23/24
# 16000/16000 [==============================] - 9s 536us/step - loss: 0.0359 - mean_squared_error: 0.0359 - val_loss: 0.0536 - val_mean_squared_error: 0.0536
# Epoch 24/24
# 16000/16000 [==============================] - 9s 536us/step - loss: 0.0357 - mean_squared_error: 0.0357 - val_loss: 0.0533 - val_mean_squared_error: 0.0533

# %%
# metric_loss = history.history['mean_squared_error']
# val_metric_loss = history.history['val_mean_squared_error']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
# plt.subplot(1, 2, 1)
plt.plot(epochs_range, loss, label='loss')
plt.plot(epochs_range, val_loss, label='val_loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

# plt.subplot(1, 2, 2)
# plt.plot(epochs_range, metric_loss, label='mean_squared_error')
# plt.plot(epochs_range, val_metric_loss, label='val_mean_squared_error')
# plt.legend(loc='upper right')
# plt.title('Training and Validation Accuracy')

plt.show()

# %%
ds = test_ds.map(lambda x,y: (x,tf.reshape(y, [-1]))).batch(BATCH_SIZE).prefetch(1)
results = model.evaluate(ds, batch_size=8)
model.predict(ds.take(1).take(1))
# Out:
# 2000/2000 [==============================] - 1s 270us/step - loss: 0.0692 - mean_squared_error: 0.0692
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f2a6d7e3c80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# array([[-3.9607608e-03, -3.9983643e-03,  2.9590729e-01,  3.1498337e-01,
#          8.7047517e-02, -3.0508568e-03, -5.3906189e-03,  1.0054498e+00,
#         -2.8237514e-03,  9.9300355e-02, -3.5060337e-03,  9.6164024e-01,
#          4.1790595e-03, -3.5875854e-03,  6.8808508e-01,  5.6907517e-01],
#        [-3.5473816e-03, -3.7132325e-03,  2.5530019e-01,  2.7940094e-01,
#          5.2834332e-02, -2.5544961e-03, -5.6712083e-03,  1.0169581e+00,
#         -2.7358974e-03,  4.1366220e-02, -3.6678594e-03,  9.8541391e-01,
#          4.0638428e-03, -3.2396014e-03,  7.5530672e-01,  4.6885484e-01],
#        [-3.1418749e-03, -2.9822714e-03,  1.4654487e-01,  2.7149189e-01,
#          2.5218844e-02, -1.9082511e-03, -6.0824766e-03,  1.0178738e+00,
#         -2.0416109e-03,  1.3607323e-02, -3.6255950e-03,  9.8272765e-01,
#          3.7656596e-03, -2.7041100e-03,  8.5932732e-01,  2.8002256e-01],
#        [-2.9977807e-03, -2.3534840e-03,  6.0705364e-02,  2.5787184e-01,
#         -1.4766097e-02, -1.4825501e-03, -6.0715093e-03,  1.0276840e+00,
#         -1.5766465e-03, -2.1611750e-02, -3.1444868e-03,  9.8244178e-01,
#          3.4600685e-03, -2.2678650e-03,  9.1826248e-01,  7.5966567e-02],
#        [-2.9202609e-03, -1.6280256e-03,  6.8464041e-02,  2.1352559e-01,
#         -5.3831577e-02, -1.2370216e-03, -6.0159187e-03,  1.0498464e+00,
#         -6.8005593e-04, -5.4222167e-02, -2.6559811e-03,  9.8849511e-01,
#          3.1278525e-03, -1.9116037e-03,  8.9219773e-01, -5.8425665e-02],
#        [-2.2509564e-03, -7.8298117e-04, -3.2550931e-02,  2.7064186e-01,
#         -7.7777028e-02, -6.1625626e-04, -5.5359770e-03,  1.0590537e+00,
#          1.0507471e-03, -2.9706240e-02, -2.3617703e-03,  9.8494434e-01,
#          2.5087777e-03, -1.2886251e-03,  7.5620604e-01, -1.2963146e-02],
#        [-1.6037717e-03, -2.8614901e-04, -1.5118098e-01,  3.4315675e-01,
#         -7.3133290e-02, -9.2429167e-05, -4.3159728e-03,  1.0402083e+00,
#          1.6246828e-03, -1.6631782e-02, -1.3732963e-03,  9.7339851e-01,
#          1.9155587e-03, -6.0500065e-04,  6.0237783e-01,  2.4671257e-02],
#        [-6.8008213e-04,  3.3673813e-04, -8.0446064e-02,  2.7083683e-01,
#         -5.7942212e-02,  2.5451701e-04, -2.9161540e-03,  1.0260144e+00,
#          2.1496685e-03, -4.3208957e-02, -4.8903259e-04,  9.8818624e-01,
#          1.0416907e-03,  1.4563062e-04,  2.8268224e-01,  1.5486915e-01]],
#       dtype=float32)

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(7,), batch_size=BATCH_SIZE),
        tf.keras.layers.Dense(256, activation='relu', batch_size=BATCH_SIZE),
        tf.keras.layers.Dense(164, activation='relu'),
        tf.keras.layers.Dense(16, name='joints_values')
    ])
    return model

model = build_model()
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (8, 256)                  2048
# _________________________________________________________________
# dense_11 (Dense)             (8, 164)                  42148
# _________________________________________________________________
# joints_values (Dense)        (8, 16)                   2640
# =================================================================
# Total params: 46,836
# Trainable params: 46,836
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=24
init_lr = 1e-4
optimizer = tf.keras.optimizers.Adam(lr=init_lr)
# optimizer = tf.keras.optimizers.SGD(lr=init_lr, momentum=0.9)

model.compile(
    optimizer = optimizer,
    loss = tf.keras.losses.MeanSquaredError(),
    metrics=[tf.keras.metrics.MeanSquaredError()])


history = model.fit(train_batches, validation_data=train_val, epochs=epochs)
# Out:
# Epoch 1/24
# 16000/16000 [==============================] - 9s 541us/step - loss: 0.0591 - mean_squared_error: 0.0591 - val_loss: 0.0543 - val_mean_squared_error: 0.0543
# Epoch 2/24
# 16000/16000 [==============================] - 9s 547us/step - loss: 0.0531 - mean_squared_error: 0.0531 - val_loss: 0.0541 - val_mean_squared_error: 0.0541
# Epoch 3/24
# 16000/16000 [==============================] - 9s 543us/step - loss: 0.0507 - mean_squared_error: 0.0507 - val_loss: 0.0549 - val_mean_squared_error: 0.0549
# Epoch 4/24
# 16000/16000 [==============================] - 9s 543us/step - loss: 0.0492 - mean_squared_error: 0.0492 - val_loss: 0.0535 - val_mean_squared_error: 0.0535
# Epoch 5/24
# 16000/16000 [==============================] - 9s 538us/step - loss: 0.0481 - mean_squared_error: 0.0481 - val_loss: 0.0530 - val_mean_squared_error: 0.0530
# Epoch 6/24
# 16000/16000 [==============================] - 9s 534us/step - loss: 0.0472 - mean_squared_error: 0.0472 - val_loss: 0.0539 - val_mean_squared_error: 0.0539
# Epoch 7/24
# 16000/16000 [==============================] - 9s 540us/step - loss: 0.0465 - mean_squared_error: 0.0465 - val_loss: 0.0527 - val_mean_squared_error: 0.0527
# Epoch 8/24
# 16000/16000 [==============================] - 9s 549us/step - loss: 0.0461 - mean_squared_error: 0.0461 - val_loss: 0.0517 - val_mean_squared_error: 0.0517
# Epoch 9/24
# 16000/16000 [==============================] - 9s 550us/step - loss: 0.0455 - mean_squared_error: 0.0455 - val_loss: 0.0519 - val_mean_squared_error: 0.0519
# Epoch 10/24
# 16000/16000 [==============================] - 9s 552us/step - loss: 0.0451 - mean_squared_error: 0.0451 - val_loss: 0.0535 - val_mean_squared_error: 0.0535
# Epoch 11/24
# 16000/16000 [==============================] - 9s 544us/step - loss: 0.0446 - mean_squared_error: 0.0446 - val_loss: 0.0539 - val_mean_squared_error: 0.0539
# Epoch 12/24
# 16000/16000 [==============================] - 9s 543us/step - loss: 0.0442 - mean_squared_error: 0.0442 - val_loss: 0.0502 - val_mean_squared_error: 0.0502
# Epoch 13/24
# 16000/16000 [==============================] - 9s 537us/step - loss: 0.0440 - mean_squared_error: 0.0440 - val_loss: 0.0528 - val_mean_squared_error: 0.0528
# Epoch 14/24
# 16000/16000 [==============================] - 9s 540us/step - loss: 0.0437 - mean_squared_error: 0.0437 - val_loss: 0.0510 - val_mean_squared_error: 0.0510
# Epoch 15/24
# 16000/16000 [==============================] - 9s 568us/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0505 - val_mean_squared_error: 0.0505
# Epoch 16/24
# 16000/16000 [==============================] - 9s 545us/step - loss: 0.0432 - mean_squared_error: 0.0432 - val_loss: 0.0509 - val_mean_squared_error: 0.0509
# Epoch 17/24
# 16000/16000 [==============================] - 9s 547us/step - loss: 0.0428 - mean_squared_error: 0.0428 - val_loss: 0.0515 - val_mean_squared_error: 0.0515
# Epoch 18/24
# 16000/16000 [==============================] - 9s 542us/step - loss: 0.0427 - mean_squared_error: 0.0427 - val_loss: 0.0504 - val_mean_squared_error: 0.0504
# Epoch 19/24
# 16000/16000 [==============================] - 9s 553us/step - loss: 0.0424 - mean_squared_error: 0.0424 - val_loss: 0.0506 - val_mean_squared_error: 0.0506
# Epoch 20/24
# 16000/16000 [==============================] - 9s 529us/step - loss: 0.0422 - mean_squared_error: 0.0422 - val_loss: 0.0514 - val_mean_squared_error: 0.0514
# Epoch 21/24
# 16000/16000 [==============================] - 9s 535us/step - loss: 0.0420 - mean_squared_error: 0.0420 - val_loss: 0.0502 - val_mean_squared_error: 0.0502
# Epoch 22/24
# 16000/16000 [==============================] - 9s 541us/step - loss: 0.0418 - mean_squared_error: 0.0418 - val_loss: 0.0517 - val_mean_squared_error: 0.0517
# Epoch 23/24
# 16000/16000 [==============================] - 9s 544us/step - loss: 0.0417 - mean_squared_error: 0.0417 - val_loss: 0.0503 - val_mean_squared_error: 0.0503
# Epoch 24/24
# 16000/16000 [==============================] - 9s 548us/step - loss: 0.0416 - mean_squared_error: 0.0416 - val_loss: 0.0504 - val_mean_squared_error: 0.0504

# %%
# metric_loss = history.history['mean_squared_error']
# val_metric_loss = history.history['val_mean_squared_error']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
# plt.subplot(1, 2, 1)
plt.plot(epochs_range, loss, label='loss')
plt.plot(epochs_range, val_loss, label='val_loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

# plt.subplot(1, 2, 2)
# plt.plot(epochs_range, metric_loss, label='mean_squared_error')
# plt.plot(epochs_range, val_metric_loss, label='val_mean_squared_error')
# plt.legend(loc='upper right')
# plt.title('Training and Validation Accuracy')

plt.show()

# %%
ds = test_ds.map(lambda x,y: (x,tf.reshape(y, [-1]))).batch(BATCH_SIZE).prefetch(1)
results = model.evaluate(ds, batch_size=8)
model.predict(ds.take(1).take(1))
# Out:
# 2000/2000 [==============================] - 1s 274us/step - loss: 0.0659 - mean_squared_error: 0.0659
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f2a6d6cb950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# array([[-4.52414999e-04,  9.91703128e-04,  4.65570427e-02,
#          4.96241063e-01, -5.37113100e-02,  4.55663285e-05,
#          1.05169544e-03,  1.09664690e+00, -2.11832827e-04,
#         -6.22128472e-02, -3.77694923e-05,  1.08450365e+00,
#         -6.41970022e-04,  1.49387182e-04,  6.08477175e-01,
#          4.22155350e-01],
#        [-6.99802709e-04,  1.10200478e-03,  1.02983817e-01,
#          4.50183690e-01, -7.75661170e-02,  6.36950572e-05,
#          8.67945142e-04,  1.12764204e+00, -9.28815789e-05,
#         -4.07622196e-03,  2.78630250e-06,  1.01964259e+00,
#         -9.09490744e-04,  2.13443127e-04,  5.92411816e-01,
#          3.47093642e-01],
#        [-7.88341218e-04,  1.08100835e-03,  1.77085206e-01,
#          4.23751354e-01, -1.48874208e-01,  6.23378000e-05,
#          7.80038070e-04,  1.19262147e+00, -1.20782497e-05,
#          6.21937588e-02,  1.39218901e-05,  9.76364255e-01,
#         -1.00272975e-03,  2.13884428e-04,  6.10060334e-01,
#          2.68332273e-01],
#        [-8.14009458e-04,  9.96495946e-04,  1.95370033e-01,
#          4.24671888e-01, -2.21672252e-01,  5.68304349e-05,
#          8.04381038e-04,  1.26860952e+00,  4.76624045e-05,
#          6.06757477e-02,  1.32136229e-05,  9.79977131e-01,
#         -1.03713584e-03,  2.02966883e-04,  6.22893929e-01,
#          2.30885580e-01],
#        [-7.77018839e-04,  8.33530969e-04,  1.93884999e-01,
#          4.12948906e-01, -2.25652888e-01,  5.00784699e-05,
#          8.95416306e-04,  1.25914073e+00,  1.01816426e-04,
#          3.25151570e-02,  1.13628594e-05,  9.94238257e-01,
#         -1.01012143e-03,  1.85175624e-04,  5.43691635e-01,
#          2.51741767e-01],
#        [-6.68438326e-04,  6.67531742e-04,  1.70256376e-01,
#          4.13885742e-01, -2.44356677e-01,  6.06448411e-05,
#          9.49008041e-04,  1.24378991e+00,  1.08830667e-04,
#         -2.11723875e-02,  1.00097168e-06,  1.03155708e+00,
#         -8.95963865e-04,  1.71884982e-04,  5.22262514e-01,
#          2.58879513e-01],
#        [-5.43601927e-04,  5.02038340e-04,  1.59133479e-01,
#          4.12750661e-01, -2.79980242e-01,  7.53237837e-05,
#          9.60196892e-04,  1.24582076e+00,  1.18282689e-04,
#         -1.41870007e-02, -1.49661719e-06,  1.00366044e+00,
#         -7.60468654e-04,  1.73763925e-04,  4.65655237e-01,
#          2.97987163e-01],
#        [-3.82322556e-04,  2.74245103e-04,  1.53552920e-01,
#          4.20841575e-01, -3.04751098e-01,  6.92223985e-05,
#          1.01550319e-03,  1.23524618e+00,  1.18855613e-04,
#          1.39640644e-04, -1.13547012e-05,  9.74062860e-01,
#         -5.96639584e-04,  1.68203114e-04,  3.46723795e-01,
#          3.69561404e-01]], dtype=float32)
